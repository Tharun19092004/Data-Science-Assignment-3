# %% [markdown]
# ## Exercise 1: Prime Numbers
# Write a Python program that checks whether a given number is prime or not. A prime number is a natural number greater than 1 that has no positive divisors other than 1 and itself.

# %%
num=int(input("Enter the number:"))
for i in range(2,num):
    if(num%i==0):
        print(num," is not a prime number")
        break
else:
    print(num,"is a prime number")
# Out:
# enter the number: 19
# 19 is a prime number

# %% [markdown]
# ## Exercise 2: Product of Random Numbers
# Develop a Python program that generates two random numbers and asks the user to enter the product of these numbers. The program should then check if the user's answer is correct and display an appropriate message.

# %%
import random

# %%
num1=random.randint(1,10)
num2=random.randint(1,10)
print("what is the product of ",num1,"and",num2)
user=int(input("Enter your answer :"))
correct_answer = num1*num2
if (user == correct_answer):
    print(correct_answer,"is Right answer")
else:
    print(correct_answer,"is wrong answer")
# Out:
# what is the product of  8 and 2
# Enter your answer : 16
# 16 is Right answer

# %% [markdown]
# ## Exercise 3: Squares of Even/Odd Numbers
# Create a Python script that prints the squares of all even or odd numbers within the range of 100 to 200. Choose either even or odd numbers and document your choice in the code.

# %%
for num in range(100,200):
    if(num%2==1):
        squar=num**2
        print(num,"the square value is",squar)
# Out:
# 101 the square value is 10201
# 103 the square value is 10609
# 105 the square value is 11025
# 107 the square value is 11449
# 109 the square value is 11881
# 111 the square value is 12321
# 113 the square value is 12769
# 115 the square value is 13225
# 117 the square value is 13689
# 119 the square value is 14161
# 121 the square value is 14641
# 123 the square value is 15129
# 125 the square value is 15625
# 127 the square value is 16129
# 129 the square value is 16641
# 131 the square value is 17161
# 133 the square value is 17689
# 135 the square value is 18225
# 137 the square value is 18769
# 139 the square value is 19321
# 141 the square value is 19881
# 143 the square value is 20449
# 145 the square value is 21025
# 147 the square value is 21609
# 149 the square value is 22201
# 151 the square value is 22801
# 153 the square value is 23409
# 155 the square value is 24025
# 157 the square value is 24649
# 159 the square value is 25281
# 161 the square value is 25921
# 163 the square value is 26569
# 165 the square value is 27225
# 167 the square value is 27889
# 169 the square value is 28561
# 171 the square value is 29241
# 173 the square value is 29929
# 175 the square value is 30625
# 177 the square value is 31329
# 179 the square value is 32041
# 181 the square value is 32761
# 183 the square value is 33489
# 185 the square value is 34225
# 187 the square value is 34969
# 189 the square value is 35721
# 191 the square value is 36481
# 193 the square value is 37249
# 195 the square value is 38025
# 197 the square value is 38809
# 199 the square value is 39601

# %% [markdown]
# ## Exercise 4: Word counter
# write a program to count the number of words in a given text.
# example:
# input_text = "This is a sample text. This text will be used to demonstrate the word counter."
# Expected output:
# 'This': 2
# 'is': 1
# 'a': 1
# 'sample': 1
# 'text.': 1

# %%
input_text = "This is a sample text. This text will be used to demonstrate the word counter."
words = input_text.split()
word_count = {}
for word in words:
    if word in word_count:
        word_count[word] += 1
    else:
        word_count[word] = 1
for word, count in word_count.items():
    print(word,":",count)
# Out:
# This : 2
# is : 1
# a : 1
# sample : 1
# text. : 1
# text : 1
# will : 1
# be : 1
# used : 1
# to : 1
# demonstrate : 1
# the : 1
# word : 1
# counter. : 1

# %% [markdown]
# ## Exercise 5: Check for Palindrome
# Write a Python function called is_palindrome that takes a string as input and returns True if the string is a palindrome, and False otherwise. A palindrome is a word, phrase, number, or other sequence of characters that reads the same forward and backward, ignoring spaces, punctuation, and capitalization.
# Example:
# Input: "racecar"
# Expected Output: True

# %%
s=input("Enter a word,phrase or number :")
revers=s[::-1]
if(s==revers):
    print(s,"is a palindrome")
else:
    print(s,"is not a palindrome")
# Out:
# Enter a word,phrase or number : 1991
# 1991 is a palindrome
